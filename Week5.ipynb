# %% [markdown]
# <a href="https://colab.research.google.com/github/Wahjoe45/PCVK_GENAP_2023/blob/main/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %%
# Gamma Correction
print ('Gamma Correction pada Citra ')
print ('---------------------------------')
try:
  gamma =  int(input('Masukkan Nilai Gamma: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/Semester 6/PCVK Tugas/Week 5/image/female.tiff')
gamma_correction = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      gamma_correction[y,x,c] = np.clip(255*pow(original[y,x,c]/255,(1/gamma)),0,255)

final_frame = cv.hconcat((original, gamma_correction))
cv2_imshow(final_frame)
# Out:
# Gamma Correction pada Citra
# ---------------------------------
# Masukkan Nilai Gamma: 6
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F75A40FFCA0>

# %%
# Image Bit Depth
print ('Simulasi Image Depth ')
print ('---------------------------------')
try:
  bit_depth =  int(input('Masukkan Nilai Bit Depth: '))
except ValueError:
  print('Error, not a number')

level = 255 / (pow(2,bit_depth)-1)

original = cv.imread('/content/drive/MyDrive/Semester 6/PCVK Tugas/Week 5/image/female.tiff', cv.IMREAD_GRAYSCALE)
depth_correction = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    depth_correction[x,y] = np.clip(round(original[x,y]/level) * level , 0,200)

final_frame = cv.hconcat((original, depth_correction))
cv2_imshow(final_frame)
# Out:
# Simulasi Image Depth
# ---------------------------------
# Masukkan Nilai Bit Depth: 2
# <PIL.Image.Image image mode=L size=512x256 at 0x7F7592EFB850>

# %%
import math
import cv2
import numpy as np

original = cv2.imread('/content/drive/MyDrive/Semester 6/PCVK Tugas/Week 5/image/noises/1.jpg')
contrast = cv2.imread('/content/drive/MyDrive/Semester 6/PCVK Tugas/Week 5/image/noises/5.jpg', 1)

def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

d = psnr(original, contrast)
print('Psnr value',d,'(dB)')

final_frame = cv.hconcat((original, contrast))
cv2_imshow(final_frame)
# Out:
# Psnr value 28.417638018925512 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F75903EC460>

# %%
import math
import cv2
import numpy as np

original = cv2.imread('/content/drive/MyDrive/Semester 6/PCVK Tugas/Week 5/image/noises/1.jpg')
contrast = cv2.imread('/content/drive/MyDrive/Semester 6/PCVK Tugas/Week 5/image/noises/30.jpg', 1)

def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

d = psnr(original, contrast)
print('Psnr value',d,'(dB)')

final_frame = cv.hconcat((original, contrast))
cv2_imshow(final_frame)
# Out:
# Psnr value 28.43565286164636 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F7590300100>

# %%
import math
import cv2
import numpy as np

original = cv2.imread('/content/drive/MyDrive/Semester 6/PCVK Tugas/Week 5/image/noises/1.jpg')
contrast = cv2.imread('/content/drive/MyDrive/Semester 6/PCVK Tugas/Week 5/image/noises/60.jpg', 1)

def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

d = psnr(original, contrast)
print('Psnr value',d,'(dB)')

final_frame = cv.hconcat((original, contrast))
cv2_imshow(final_frame)
# Out:
# Psnr value 28.435122992674202 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F75903EC1F0>

# %%
import math
import cv2
import numpy as np

original = cv2.imread('/content/drive/MyDrive/Semester 6/PCVK Tugas/Week 5/image/noises/1.jpg')
contrast = cv2.imread('/content/drive/MyDrive/Semester 6/PCVK Tugas/Week 5/image/noises/80.jpg', 1)

def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

d = psnr(original, contrast)
print('Psnr value',d,'(dB)')

final_frame = cv.hconcat((original, contrast))
cv2_imshow(final_frame)
# Out:
# Psnr value 28.428328479224664 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F75903009D0>

# %%
import math
import cv2
import numpy as np

original = cv2.imread('/content/drive/MyDrive/Semester 6/PCVK Tugas/Week 5/image/noises/1.jpg')
contrast = cv2.imread('/content/drive/MyDrive/Semester 6/PCVK Tugas/Week 5/image/noises/100.jpg', 1)

def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

d = psnr(original, contrast)
print('Psnr value',d,'(dB)')

final_frame = cv.hconcat((original, contrast))
cv2_imshow(final_frame)
# Out:
# Psnr value 28.43504218746719 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F75903ECF70>
