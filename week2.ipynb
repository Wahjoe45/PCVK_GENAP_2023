# %% [markdown]
# <a href="https://colab.research.google.com/github/Wahjoe45/PCVK_GENAP_2023/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Percobaan

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Fighter01.jpg')
plt.imshow(img)
# Membuka file gambar yang ada di gdrive

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)
# Membaca image dan menyimpan dalam channel warna RGB

# %%
img_gray = cv.imread('/content/drive/MyDrive/Fighter01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)
# Menampilkan citra melakukan resizing, melakukan Flipping, Menyimpan citra hasil

# %%
plt.imshow(img_gray, cmap='gray')
# Menampilkan gambar dalam citra grayscale

# %%
plt.imshow(img_gray, cmap='magma')
# Menampilkan gambar dengan colormap warna 'magma'

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)
# Resize menjadi ukuran panjang 512 dan lebar 1024

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

# Simpan file image
# cv.imwrite('/content/drive/MyDrive/Semester 6/PCVK/image', img5)

# Menampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))  # ubah - ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
# Membuat bentuk geometri 2D dari OpenCV
# Membuat black image dengan type data int16
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
# Perhatikan koordinat titik pt1 dan pt2
# membuat persegi panjang berwarna hijau koordinat pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
# membuat persegi panjang berwarna biru sesuai koordinat pt1 dan pt2
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
# membuat lingkaran sesuai radius yang tertulis pada kode
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
# menambah garis sesuai koordinat pt1 dan pt2
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
# membuat lingkaran sesuai radius dan koordinat yang tertulis pada kode
cv.circle(black_img,center=(400,400),radius=10,color=(255,0,0),thickness=100)
plt.imshow(black_img)

# %%
# Pembuatan kalimat string pada gambar
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
# pembuatan ulang black image dengan type data int32
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
# Inisialisai NumPY array dengan tipe data int32 
vertices = np.array([[100,300], [200,200], [400,300], [200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
# nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R,G,B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
# Penambahan polyline pada black image kedua
cv.polylines(black_img2,[pts],isClosed=True, color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
# Tugas 1 menampilkan channel red dan blue pada gambar
img = cv.imread('/content/drive/MyDrive/Fighter01.jpg')
redblue = cv.cvtColor(img,cv.COLOR_BGR2RGB) # Convert BGR ke RGB
R,G,B = cv.split(redblue) # Split antara variable RGB
zeros = np.zeros(redblue.shape[:2], dtype="uint8") # fungsi zeros untuk membuat semua matriks menjadi bernilai 0
rb = cv.merge([R,zeros,B]) # Membuat warna menjadi red blue dengan cara merubah nilai pada channel green menjadi zero
plt.imshow(rb)

# %%
# Tugas 2 menampilkan channel green dan blue pada gambar
img = cv.imread('/content/drive/MyDrive/Fighter01.jpg')
greenblue = cv.cvtColor(img,cv.COLOR_BGR2RGB) # Convert BGR ke RGB
R,G,B = cv.split(greenblue)
zeros = np.zeros(greenblue.shape[:2], dtype="uint8") # fungsi zeros untuk membuat semua matriks menjadi bernilai 0
gb = cv.merge([zeros,G,B]) # Membuat warna green blue dengan cara memrubah nilai pada channel red menjadi zero
plt.imshow(gb)

# %%
# Tugas 3 Tampilkan image baris ke 20-115, kolom 25-120!
plt.imshow(img[20:115, 25:120])

# %%
# Tugas 4 Tampilkan image baris ke 5-30, semua kolom, channel Red saja!
color = cv.merge([R,zeros,zeros])
y=5
x=0
h=30
w=color.shape[1]
show = color[y:h, x:w]
plt.imshow(show)

# %%
# Tugas 5 Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!
rect = cv.imread('/content/drive/MyDrive/Fighter01.jpg')
rect = cv.cvtColor(rect,cv.COLOR_BGR2RGB)
cv.rectangle(rect, pt1=(450,350), pt2=(90,120), color=(0,0,255), thickness=10)  # Blue
cv.rectangle(rect, pt1=(700,300), pt2=(200,600), color=(0,255,0),thickness=10) # Green
cv.rectangle(rect, pt1=(500,400), pt2=(300,200), color=(255,255,255),thickness=10) # White
cv.rectangle(rect, pt1=(100,350), pt2=(550,450), color=(255,255,0),thickness=10) # Yellow
cv.rectangle(rect, pt1=(300,350), pt2=(600,50), color=(0,255,255),thickness=10) # Cyan 
plt.imshow(rect)

# %%
# Tugas 6 Tampilkan image dengan posisi terbalik!
rect = cv.flip(cv.cvtColor(rect,cv.COLOR_BGR2RGB),0)
plt.imshow(rect)

# %%
# Tugas 7 Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto)
actv = cv.imread('/content/drive/MyDrive/Semester 6/PCVK/image/activity.jpg')
actv = cv.cvtColor(actv,cv.COLOR_BGR2RGB)
cv.rectangle(actv, pt1=(850,600), pt2=(480,120), color=(0,0,255), thickness=10)  # Blue
cv.circle(actv,center=(680,400),radius=200,color=(255,0,0),thickness=10) # Red
plt.imshow(actv)

# %%
# Tugas 8 Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

actv = cv.imread('/content/drive/MyDrive/Semester 6/PCVK/image/activity.jpg') # Membaca file yang ada di gdrive
actv = cv.cvtColor(actv,cv.COLOR_BGR2RGB) # Convert image ke warna RGB
cv.rectangle(actv, pt1=(50,570), pt2=(300,680), color=(0,0,255), thickness=10)  # Blue
plt.imshow(actv)

# %%
actv = cv.imread('/content/drive/MyDrive/Semester 6/PCVK/image/activity.jpg')
actv = cv.cvtColor(actv,cv.COLOR_BGR2RGB)
cv.putText(actv,text='Hello Arya',org=(10,650),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(actv)
